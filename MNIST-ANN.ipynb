# %% [markdown]
# <a href="https://colab.research.google.com/github/Rupeshgarsondiya/Deep-Learning/blob/main/MNIST-ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.models import Sequential
import numpy as np
import matplotlib.pyplot as plt




#load data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
print(train_images.shape)
print(test_images.shape)
print(train_labels.shape)
print(test_labels.shape)

# scalling the pixel value
train_images = train_images / 255.0
test_images = test_images / 255.0

Flatten

# Design nureal network
model = Sequential()
model.add(Flatten(input_shape=(28,28)))
model.add(Dense(128,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.summary()


# Here we also use loss function as a categorical_crossentropy but when we use  sparse_categorical_crossentropy then not convert encode to output column in multiclass classification
# if i work on multiclass classification problem and loss use as categorical_crossentropy then must convert output column in encoding from
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history = model.fit(train_images,train_labels,epochs=10,validation_split=0.2)
test_loss,test_acc = model.evaluate(test_images,test_labels)
print('test_acc:',test_acc)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000,)
# (10000,)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_5 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_56 (Dense)                     │ (None, 128)                 │         100,480 │
# ...

# %%
# model predication
y_pred = model.predict(test_images)
print(y_pred)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# [[9.44067047e-11 1.00989155e-08 2.57433075e-09 ... 9.99991715e-01
#   1.17774712e-09 8.10653546e-06]
#  [3.10091230e-10 1.33619507e-08 9.99997079e-01 ... 4.67820727e-10
#   2.87243006e-06 2.68485733e-12]
#  [1.13863616e-05 9.98626173e-01 1.20403720e-05 ... 1.83699260e-04
#   1.10044004e-03 1.14651903e-06]
#  ...
#  [4.46489860e-16 9.99350125e-13 1.45188901e-13 ... 1.90004705e-08
#   1.57425774e-11 2.94463348e-06]
#  [9.77291997e-11 3.55388566e-11 1.01293833e-15 ... 3.27769754e-15
#   1.02726247e-07 7.52049187e-11]
#  [6.10745343e-10 1.90606320e-12 1.25795605e-15 ... 2.28640993e-14
#   5.79432726e-12 2.25230550e-15]]

# %%
y_pred = np.argmax(y_pred,axis=1)
print(y_pred)
# Out:
# [7 2 1 ... 4 5 6]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
acc = accuracy_score(test_labels,y_pred)
print("Accuracy : ",acc)
cm = confusion_matrix(test_labels,y_pred)
print(cm)
# Out:
# Accuracy :  0.9776
# [[ 971    0    0    0    2    0    2    1    3    1]
#  [   0 1112    3    3    0    0    6    0   11    0]
#  [   6    0 1003    7    2    0    3    3    7    1]
#  [   0    0    0  981    0    8    0    5    9    7]
#  [   1    0    1    0  967    0    5    1    0    7]
#  [   1    0    0    6    1  868    5    0    8    3]
#  [   4    1    0    1    7    4  940    0    1    0]
#  [   1    1    9    2    1    2    0 1003    4    5]
#  [   4    0    3    2    3    4    1    2  950    5]
#  [   2    2    0    2   10    4    1    3    4  981]]

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.show()

# %%
import random
i =random.randint(1,10000)
y_pred1 = model.predict(test_images[i].reshape(1,28,28))
y_pred1 = np.argmax(y_pred1,axis=1)
print("Prediction : ",y_pred1)
print("Actual : ",test_labels[i])
plt.imshow(test_images[i])
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Prediction :  [7]
# Actual :  7
